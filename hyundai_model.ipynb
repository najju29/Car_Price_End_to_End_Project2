# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pickle

# %%
df=pd.read_csv('Hyundai.csv')

# %%
df.head()
# Out:
#    year  selling_price  km_driven    fuel seller_type transmission  \
# 0  2012         600000     100000  Diesel  Individual       Manual
# 1  2016         550000      25000  Petrol  Individual       Manual
# 2  2015         850000      25000  Petrol  Individual       Manual
# 3  2012         600000     100000  Diesel  Individual       Manual
# 4  2016         550000      25000  Petrol  Individual       Manual
#
#          owner Car_Company         Model_Name
# 0  First Owner     Hyundai       Verna 1.6 SX
# 1  First Owner     Hyundai  Xcent 1.2 Kappa S
# 2  First Owner     Hyundai   Creta 1.6 VTVT S
# 3  First Owner     Hyundai       Verna 1.6 SX
# 4  First Owner     Hyundai  Xcent 1.2 Kappa S

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 821 entries, 0 to 820
# Data columns (total 9 columns):
# year             821 non-null int64
# selling_price    821 non-null int64
# km_driven        821 non-null int64
# fuel             821 non-null object
# seller_type      821 non-null object
# transmission     821 non-null object
# owner            821 non-null object
# Car_Company      821 non-null object
# Model_Name       821 non-null object
# dtypes: int64(3), object(6)
# memory usage: 57.9+ KB

# %%
df.drop('Car_Company',axis=1,inplace=True)

# %%
df.head()
# Out:
#    year  selling_price  km_driven    fuel seller_type transmission  \
# 0  2012         600000     100000  Diesel  Individual       Manual
# 1  2016         550000      25000  Petrol  Individual       Manual
# 2  2015         850000      25000  Petrol  Individual       Manual
# 3  2012         600000     100000  Diesel  Individual       Manual
# 4  2016         550000      25000  Petrol  Individual       Manual
#
#          owner         Model_Name
# 0  First Owner       Verna 1.6 SX
# 1  First Owner  Xcent 1.2 Kappa S
# 2  First Owner   Creta 1.6 VTVT S
# 3  First Owner       Verna 1.6 SX
# 4  First Owner  Xcent 1.2 Kappa S

# %%
model_names=list(df['Model_Name'].unique())

# %%
len(model_names)
# Out:
# 244

# %%
avg_prices=[]
for i in model_names:
    avg_prices.append(df[df['Model_Name']==i]['selling_price'].mean())

# %%
models_df=pd.DataFrame({'Model_name':model_names,'Avg_selling_price':avg_prices})

# %%
models_df
# Out:
#                        Model_name  Avg_selling_price
# 0                    Verna 1.6 SX           490666.4
# 1               Xcent 1.2 Kappa S           430000.0
# 2                Creta 1.6 VTVT S           862500.0
# 3             Venue SX Opt Diesel          1097500.0
# 4                  i10 Magna 1.1L           262499.5
# ..                            ...                ...
# 239             Xcent 1.2 CRDi SX           399000.0
# 240          Verna CRDi 1.6 AT EX          1100000.0
# 241  Santro Xing XS eRLX Euro III           145000.0
# 242                     Santro AT           145000.0
# 243            i20 Magna 1.4 CRDi           409999.0
#
# [244 rows x 2 columns]

# %%
models_dict={}

# %%
for i in range(0,244):
    models_dict.update([(model_names[i],avg_prices[i])])

# %%
len(models_dict)
# Out:
# 244

# %%
Newf_df=df.copy()

# %%
Newf_df.head()
# Out:
#    year  selling_price  km_driven    fuel seller_type transmission  \
# 0  2012         600000     100000  Diesel  Individual       Manual
# 1  2016         550000      25000  Petrol  Individual       Manual
# 2  2015         850000      25000  Petrol  Individual       Manual
# 3  2012         600000     100000  Diesel  Individual       Manual
# 4  2016         550000      25000  Petrol  Individual       Manual
#
#          owner         Model_Name
# 0  First Owner       Verna 1.6 SX
# 1  First Owner  Xcent 1.2 Kappa S
# 2  First Owner   Creta 1.6 VTVT S
# 3  First Owner       Verna 1.6 SX
# 4  First Owner  Xcent 1.2 Kappa S

# %%
Newf_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 821 entries, 0 to 820
# Data columns (total 8 columns):
# year             821 non-null int64
# selling_price    821 non-null int64
# km_driven        821 non-null int64
# fuel             821 non-null object
# seller_type      821 non-null object
# transmission     821 non-null object
# owner            821 non-null object
# Model_Name       821 non-null object
# dtypes: int64(3), object(5)
# memory usage: 51.4+ KB

# %%
Newf_df['Model_Name']=Newf_df['Model_Name'].map(models_dict)

# %%
fuel_input={'Petrol':0,'CNG':1,'Diesel':2,'LPG':3}

# %%
Newf_df['fuel']=Newf_df['fuel'].map(fuel_input)

# %%
seller_input={'Individual':0,'Dealer':1,'Trustmark Dealer':2}

Newf_df['seller_type']=Newf_df['seller_type'].map(seller_input)

# %%
trans_input={'Manual':0,'Automatic':1}
    
Newf_df['transmission']=Newf_df['transmission'].map(trans_input)

# %%
owner_input={'First Owner':0,'Second Owner':1,'Third Owner':2,'Fourth & Above Owner':3}

Newf_df['owner']=Newf_df['owner'].map(owner_input)

# %%
Newf_df
# Out:
#      year  selling_price  km_driven  fuel  seller_type  transmission  owner  \
# 0    2012         600000     100000     2            0             0      0
# 1    2016         550000      25000     0            0             0      0
# 2    2015         850000      25000     0            0             0      0
# 3    2012         600000     100000     2            0             0      0
# 4    2016         550000      25000     0            0             0      0
# ..    ...            ...        ...   ...          ...           ...    ...
# 816  2011         235000      43100     0            1             0      0
# 817  2013         500000     120000     2            0             0      0
# 818  2014         409999      80000     2            0             0      1
# 819  2014         409999      80000     2            0             0      1
# 820  2016         865000      90000     2            0             0      0
#
#        Model_Name
# 0    4.906664e+05
# 1    4.300000e+05
# 2    8.625000e+05
# 3    4.906664e+05
# 4    4.300000e+05
# ..            ...
# 816  2.063000e+05
# 817  4.910714e+05
# 818  3.709998e+05
# 819  4.099990e+05
# 820  1.186667e+06
#
# [821 rows x 8 columns]

# %%
y=Newf_df['selling_price']

# %%
Newf_df.drop('selling_price',axis=1,inplace=True)

# %%
from sklearn.model_selection import GridSearchCV

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
random_params={'n_estimators':[250,260,275,285,300],'max_depth':[9,10,11],'min_samples_leaf':[1,2,3]}

# %%
random_grid=GridSearchCV(estimator=RandomForestRegressor(),param_grid=random_params,cv=5,verbose=3)

# %%
random_grid.fit(Newf_df,y)
# Out:
# Fitting 5 folds for each of 45 candidates, totalling 225 fits
# [CV] max_depth=9, min_samples_leaf=1, n_estimators=250 ...............
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [CV]  max_depth=9, min_samples_leaf=1, n_estimators=250, score=0.963, total=   1.1s
# [CV] max_depth=9, min_samples_leaf=1, n_estimators=250 ...............
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    1.0s remaining:    0.0s
# [CV]  max_depth=9, min_samples_leaf=1, n_estimators=250, score=0.936, total=   1.5s
# [CV] max_depth=9, min_samples_leaf=1, n_estimators=250 ...............
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    2.6s remaining:    0.0s
# [CV]  max_depth=9, min_samples_leaf=1, n_estimators=250, score=0.947, total=   1.0s
# [CV] max_depth=9, min_samples_leaf=1, n_estimators=250 ...............
# [CV]  max_depth=9, min_samples_leaf=1, n_estimators=250, score=0.933, total=   1.1s
# [CV] max_depth=9, min_samples_leaf=1, n_estimators=250 ...............
# [CV]  max_depth=9, min_samples_leaf=1, n_estimators=250, score=0.903, total=   1.0s
# [CV] max_depth=9, min_samples_leaf=1, n_estimators=260 ...............
# [CV]  max_depth=9, min_samples_leaf=1, n_estimators=260, score=0.963, total=   1.1s
# [CV] max_depth=9, min_samples_leaf=1, n_estimators=260 ...............
# [CV]  max_depth=9, min_samples_leaf=1, n_estimators=260, score=0.938, total=   1.0s
# [CV] max_depth=9, min_samples_leaf=1, n_estimators=260 ...............
# [CV]  max_depth=9, min_samples_leaf=1, n_estimators=260, score=0.947, total=   0.9s
# [CV] max_depth=9, min_samples_leaf=1, n_estimators=260 ...............
# [CV]  max_depth=9, min_samples_leaf=1, n_estimators=260, score=0.936, total=   1.0s
# [CV] max_depth=9, min_samples_leaf=1, n_estimators=260 ...............
# [CV]  max_depth=9, min_samples_leaf=1, n_estimators=260, score=0.904, total=   1.1s
# [CV] max_depth=9, min_samples_leaf=1, n_estimators=275 ...............
# [CV]  max_depth=9, min_samples_leaf=1, n_estimators=275, score=0.962, total=   1.3s
# [CV] max_depth=9, min_samples_leaf=1, n_estimators=275 ...............
# [CV]  max_depth=9, min_samples_leaf=1, n_estimators=275, score=0.936, total=   1.1s
# [CV] max_depth=9, min_samples_leaf=1, n_estimators=275 ...............
# [CV]  max_depth=9, min_samples_leaf=1, n_estimators=275, score=0.948, total=   1.1s
# [CV] max_depth=9, min_samples_leaf=1, n_estimators=275 ...............
# [CV]  max_depth=9, min_samples_leaf=1, n_estimators=275, score=0.935, total=   1.3s
# [CV] max_depth=9, min_samples_leaf=1, n_estimators=275 ...............
# [CV]  max_depth=9, min_samples_leaf=1, n_estimators=275, score=0.902, total=   1.4s
# [CV] max_depth=9, min_samples_leaf=1, n_estimators=285 ...............
# [CV]  max_depth=9, min_samples_leaf=1, n_estimators=285, score=0.962, total=   1.4s
# [CV] max_depth=9, min_samples_leaf=1, n_estimators=285 ...............
# [CV]  max_depth=9, min_samples_leaf=1, n_estimators=285, score=0.937, total=   1.2s
# [CV] max_depth=9, min_samples_leaf=1, n_estimators=285 ...............
# [CV]  max_depth=9, min_samples_leaf=1, n_estimators=285, score=0.948, total=   1.1s
# [CV] max_depth=9, min_samples_leaf=1, n_estimators=285 ...............
# [CV]  max_depth=9, min_samples_leaf=1, n_estimators=285, score=0.933, total=   1.1s
# [CV] max_depth=9, min_samples_leaf=1, n_estimators=285 ...............
# [CV]  max_depth=9, min_samples_leaf=1, n_estimators=285, score=0.901, total=   1.1s
# [CV] max_depth=9, min_samples_leaf=1, n_estimators=300 ...............
# [CV]  max_depth=9, min_samples_leaf=1, n_estimators=300, score=0.963, total=   1.2s
# [CV] max_depth=9, min_samples_leaf=1, n_estimators=300 ...............
# [CV]  max_depth=9, min_samples_leaf=1, n_estimators=300, score=0.938, total=   1.2s
# [CV] max_depth=9, min_samples_leaf=1, n_estimators=300 ...............
# [CV]  max_depth=9, min_samples_leaf=1, n_estimators=300, score=0.946, total=   1.1s
# [CV] max_depth=9, min_samples_leaf=1, n_estimators=300 ...............
# [CV]  max_depth=9, min_samples_leaf=1, n_estimators=300, score=0.935, total=   1.2s
# [CV] max_depth=9, min_samples_leaf=1, n_estimators=300 ...............
# [CV]  max_depth=9, min_samples_leaf=1, n_estimators=300, score=0.901, total=   1.3s
# [CV] max_depth=9, min_samples_leaf=2, n_estimators=250 ...............
# [CV]  max_depth=9, min_samples_leaf=2, n_estimators=250, score=0.961, total=   0.9s
# [CV] max_depth=9, min_samples_leaf=2, n_estimators=250 ...............
# [CV]  max_depth=9, min_samples_leaf=2, n_estimators=250, score=0.932, total=   0.9s
# [CV] max_depth=9, min_samples_leaf=2, n_estimators=250 ...............
# [CV]  max_depth=9, min_samples_leaf=2, n_estimators=250, score=0.947, total=   1.3s
# [CV] max_depth=9, min_samples_leaf=2, n_estimators=250 ...............
# [CV]  max_depth=9, min_samples_leaf=2, n_estimators=250, score=0.939, total=   1.0s
# [CV] max_depth=9, min_samples_leaf=2, n_estimators=250 ...............
# [CV]  max_depth=9, min_samples_leaf=2, n_estimators=250, score=0.897, total=   1.0s
# [CV] max_depth=9, min_samples_leaf=2, n_estimators=260 ...............
# [CV]  max_depth=9, min_samples_leaf=2, n_estimators=260, score=0.960, total=   0.9s
# [CV] max_depth=9, min_samples_leaf=2, n_estimators=260 ...............
# [CV]  max_depth=9, min_samples_leaf=2, n_estimators=260, score=0.931, total=   1.1s
# [CV] max_depth=9, min_samples_leaf=2, n_estimators=260 ...............
# [CV]  max_depth=9, min_samples_leaf=2, n_estimators=260, score=0.948, total=   1.1s
# [CV] max_depth=9, min_samples_leaf=2, n_estimators=260 ...............
# [CV]  max_depth=9, min_samples_leaf=2, n_estimators=260, score=0.940, total=   1.1s
# [CV] max_depth=9, min_samples_leaf=2, n_estimators=260 ...............
# [CV]  max_depth=9, min_samples_leaf=2, n_estimators=260, score=0.897, total=   1.0s
# [CV] max_depth=9, min_samples_leaf=2, n_estimators=275 ...............
# [CV]  max_depth=9, min_samples_leaf=2, n_estimators=275, score=0.960, total=   1.0s
# [CV] max_depth=9, min_samples_leaf=2, n_estimators=275 ...............
# [CV]  max_depth=9, min_samples_leaf=2, n_estimators=275, score=0.931, total=   1.1s
# [CV] max_depth=9, min_samples_leaf=2, n_estimators=275 ...............
# [CV]  max_depth=9, min_samples_leaf=2, n_estimators=275, score=0.946, total=   1.1s
# [CV] max_depth=9, min_samples_leaf=2, n_estimators=275 ...............
# [CV]  max_depth=9, min_samples_leaf=2, n_estimators=275, score=0.939, total=   1.0s
# [CV] max_depth=9, min_samples_leaf=2, n_estimators=275 ...............
# [CV]  max_depth=9, min_samples_leaf=2, n_estimators=275, score=0.900, total=   1.0s
# [CV] max_depth=9, min_samples_leaf=2, n_estimators=285 ...............
# [CV]  max_depth=9, min_samples_leaf=2, n_estimators=285, score=0.961, total=   1.1s
# [CV] max_depth=9, min_samples_leaf=2, n_estimators=285 ...............
# [CV]  max_depth=9, min_samples_leaf=2, n_estimators=285, score=0.931, total=   1.3s
# [CV] max_depth=9, min_samples_leaf=2, n_estimators=285 ...............
# [CV]  max_depth=9, min_samples_leaf=2, n_estimators=285, score=0.948, total=   1.8s
# [CV] max_depth=9, min_samples_leaf=2, n_estimators=285 ...............
# [CV]  max_depth=9, min_samples_leaf=2, n_estimators=285, score=0.939, total=   1.3s
# [CV] max_depth=9, min_samples_leaf=2, n_estimators=285 ...............
# [CV]  max_depth=9, min_samples_leaf=2, n_estimators=285, score=0.896, total=   1.4s
# [CV] max_depth=9, min_samples_leaf=2, n_estimators=300 ...............
# [CV]  max_depth=9, min_samples_leaf=2, n_estimators=300, score=0.960, total=   1.3s
# [CV] max_depth=9, min_samples_leaf=2, n_estimators=300 ...............
# [CV]  max_depth=9, min_samples_leaf=2, n_estimators=300, score=0.932, total=   1.5s
# [CV] max_depth=9, min_samples_leaf=2, n_estimators=300 ...............
# [CV]  max_depth=9, min_samples_leaf=2, n_estimators=300, score=0.948, total=   1.2s
# [CV] max_depth=9, min_samples_leaf=2, n_estimators=300 ...............
# [CV]  max_depth=9, min_samples_leaf=2, n_estimators=300, score=0.940, total=   1.3s
# [CV] max_depth=9, min_samples_leaf=2, n_estimators=300 ...............
# [CV]  max_depth=9, min_samples_leaf=2, n_estimators=300, score=0.900, total=   1.2s
# [CV] max_depth=9, min_samples_leaf=3, n_estimators=250 ...............
# [CV]  max_depth=9, min_samples_leaf=3, n_estimators=250, score=0.958, total=   1.0s
# [CV] max_depth=9, min_samples_leaf=3, n_estimators=250 ...............
# [CV]  max_depth=9, min_samples_leaf=3, n_estimators=250, score=0.928, total=   1.1s
# [CV] max_depth=9, min_samples_leaf=3, n_estimators=250 ...............
# [CV]  max_depth=9, min_samples_leaf=3, n_estimators=250, score=0.946, total=   1.0s
# [CV] max_depth=9, min_samples_leaf=3, n_estimators=250 ...............
# [CV]  max_depth=9, min_samples_leaf=3, n_estimators=250, score=0.941, total=   1.1s
# [CV] max_depth=9, min_samples_leaf=3, n_estimators=250 ...............
# [CV]  max_depth=9, min_samples_leaf=3, n_estimators=250, score=0.896, total=   1.0s
# [CV] max_depth=9, min_samples_leaf=3, n_estimators=260 ...............
# [CV]  max_depth=9, min_samples_leaf=3, n_estimators=260, score=0.958, total=   1.3s
# [CV] max_depth=9, min_samples_leaf=3, n_estimators=260 ...............
# [CV]  max_depth=9, min_samples_leaf=3, n_estimators=260, score=0.930, total=   1.1s
# [CV] max_depth=9, min_samples_leaf=3, n_estimators=260 ...............
# [CV]  max_depth=9, min_samples_leaf=3, n_estimators=260, score=0.947, total=   1.1s
# [CV] max_depth=9, min_samples_leaf=3, n_estimators=260 ...............
# [CV]  max_depth=9, min_samples_leaf=3, n_estimators=260, score=0.940, total=   1.2s
# [CV] max_depth=9, min_samples_leaf=3, n_estimators=260 ...............
# [CV]  max_depth=9, min_samples_leaf=3, n_estimators=260, score=0.899, total=   1.1s
# [CV] max_depth=9, min_samples_leaf=3, n_estimators=275 ...............
# [CV]  max_depth=9, min_samples_leaf=3, n_estimators=275, score=0.958, total=   1.1s
# [CV] max_depth=9, min_samples_leaf=3, n_estimators=275 ...............
# [CV]  max_depth=9, min_samples_leaf=3, n_estimators=275, score=0.927, total=   1.2s
# [CV] max_depth=9, min_samples_leaf=3, n_estimators=275 ...............
# [CV]  max_depth=9, min_samples_leaf=3, n_estimators=275, score=0.947, total=   1.2s
# [CV] max_depth=9, min_samples_leaf=3, n_estimators=275 ...............
# [CV]  max_depth=9, min_samples_leaf=3, n_estimators=275, score=0.940, total=   1.1s
# [CV] max_depth=9, min_samples_leaf=3, n_estimators=275 ...............
# [CV]  max_depth=9, min_samples_leaf=3, n_estimators=275, score=0.896, total=   1.2s
# [CV] max_depth=9, min_samples_leaf=3, n_estimators=285 ...............
# [CV]  max_depth=9, min_samples_leaf=3, n_estimators=285, score=0.958, total=   1.2s
# [CV] max_depth=9, min_samples_leaf=3, n_estimators=285 ...............
# [CV]  max_depth=9, min_samples_leaf=3, n_estimators=285, score=0.929, total=   1.1s
# [CV] max_depth=9, min_samples_leaf=3, n_estimators=285 ...............
# [CV]  max_depth=9, min_samples_leaf=3, n_estimators=285, score=0.947, total=   1.3s
# [CV] max_depth=9, min_samples_leaf=3, n_estimators=285 ...............
# [CV]  max_depth=9, min_samples_leaf=3, n_estimators=285, score=0.939, total=   1.4s
# [CV] max_depth=9, min_samples_leaf=3, n_estimators=285 ...............
# [CV]  max_depth=9, min_samples_leaf=3, n_estimators=285, score=0.902, total=   1.4s
# [CV] max_depth=9, min_samples_leaf=3, n_estimators=300 ...............
# [CV]  max_depth=9, min_samples_leaf=3, n_estimators=300, score=0.958, total=   1.2s
# [CV] max_depth=9, min_samples_leaf=3, n_estimators=300 ...............
# [CV]  max_depth=9, min_samples_leaf=3, n_estimators=300, score=0.929, total=   1.1s
# [CV] max_depth=9, min_samples_leaf=3, n_estimators=300 ...............
# [CV]  max_depth=9, min_samples_leaf=3, n_estimators=300, score=0.946, total=   1.0s
# [CV] max_depth=9, min_samples_leaf=3, n_estimators=300 ...............
# [CV]  max_depth=9, min_samples_leaf=3, n_estimators=300, score=0.939, total=   1.3s
# [CV] max_depth=9, min_samples_leaf=3, n_estimators=300 ...............
# [CV]  max_depth=9, min_samples_leaf=3, n_estimators=300, score=0.898, total=   1.1s
# [CV] max_depth=10, min_samples_leaf=1, n_estimators=250 ..............
# [CV]  max_depth=10, min_samples_leaf=1, n_estimators=250, score=0.963, total=   1.5s
# [CV] max_depth=10, min_samples_leaf=1, n_estimators=250 ..............
# [CV]  max_depth=10, min_samples_leaf=1, n_estimators=250, score=0.936, total=   1.1s
# [CV] max_depth=10, min_samples_leaf=1, n_estimators=250 ..............
# [CV]  max_depth=10, min_samples_leaf=1, n_estimators=250, score=0.948, total=   1.8s
# [CV] max_depth=10, min_samples_leaf=1, n_estimators=250 ..............
# [CV]  max_depth=10, min_samples_leaf=1, n_estimators=250, score=0.935, total=   1.2s
# [CV] max_depth=10, min_samples_leaf=1, n_estimators=250 ..............
# [CV]  max_depth=10, min_samples_leaf=1, n_estimators=250, score=0.903, total=   1.7s
# [CV] max_depth=10, min_samples_leaf=1, n_estimators=260 ..............
# [CV]  max_depth=10, min_samples_leaf=1, n_estimators=260, score=0.963, total=   1.6s
# [CV] max_depth=10, min_samples_leaf=1, n_estimators=260 ..............
# [CV]  max_depth=10, min_samples_leaf=1, n_estimators=260, score=0.936, total=   1.7s
# [CV] max_depth=10, min_samples_leaf=1, n_estimators=260 ..............
# [CV]  max_depth=10, min_samples_leaf=1, n_estimators=260, score=0.946, total=   1.5s
# [CV] max_depth=10, min_samples_leaf=1, n_estimators=260 ..............
# [CV]  max_depth=10, min_samples_leaf=1, n_estimators=260, score=0.935, total=   1.4s
# [CV] max_depth=10, min_samples_leaf=1, n_estimators=260 ..............
# [CV]  max_depth=10, min_samples_leaf=1, n_estimators=260, score=0.904, total=   1.4s
# [CV] max_depth=10, min_samples_leaf=1, n_estimators=275 ..............
# [CV]  max_depth=10, min_samples_leaf=1, n_estimators=275, score=0.963, total=   1.6s
# [CV] max_depth=10, min_samples_leaf=1, n_estimators=275 ..............
# [CV]  max_depth=10, min_samples_leaf=1, n_estimators=275, score=0.939, total=   1.6s
# [CV] max_depth=10, min_samples_leaf=1, n_estimators=275 ..............
# [CV]  max_depth=10, min_samples_leaf=1, n_estimators=275, score=0.946, total=   1.5s
# [CV] max_depth=10, min_samples_leaf=1, n_estimators=275 ..............
# [CV]  max_depth=10, min_samples_leaf=1, n_estimators=275, score=0.936, total=   1.8s
# [CV] max_depth=10, min_samples_leaf=1, n_estimators=275 ..............
# [CV]  max_depth=10, min_samples_leaf=1, n_estimators=275, score=0.903, total=   1.8s
# [CV] max_depth=10, min_samples_leaf=1, n_estimators=285 ..............
# [CV]  max_depth=10, min_samples_leaf=1, n_estimators=285, score=0.963, total=   1.8s
# [CV] max_depth=10, min_samples_leaf=1, n_estimators=285 ..............
# [CV]  max_depth=10, min_samples_leaf=1, n_estimators=285, score=0.937, total=   2.3s
# [CV] max_depth=10, min_samples_leaf=1, n_estimators=285 ..............
# [CV]  max_depth=10, min_samples_leaf=1, n_estimators=285, score=0.946, total=   1.7s
# [CV] max_depth=10, min_samples_leaf=1, n_estimators=285 ..............
# [CV]  max_depth=10, min_samples_leaf=1, n_estimators=285, score=0.934, total=   1.7s
# [CV] max_depth=10, min_samples_leaf=1, n_estimators=285 ..............
# [CV]  max_depth=10, min_samples_leaf=1, n_estimators=285, score=0.903, total=   2.0s
# [CV] max_depth=10, min_samples_leaf=1, n_estimators=300 ..............
# [CV]  max_depth=10, min_samples_leaf=1, n_estimators=300, score=0.964, total=   1.9s
# [CV] max_depth=10, min_samples_leaf=1, n_estimators=300 ..............
# [CV]  max_depth=10, min_samples_leaf=1, n_estimators=300, score=0.939, total=   2.0s
# [CV] max_depth=10, min_samples_leaf=1, n_estimators=300 ..............
# [CV]  max_depth=10, min_samples_leaf=1, n_estimators=300, score=0.947, total=   1.9s
# [CV] max_depth=10, min_samples_leaf=1, n_estimators=300 ..............
# [CV]  max_depth=10, min_samples_leaf=1, n_estimators=300, score=0.937, total=   1.6s
# [CV] max_depth=10, min_samples_leaf=1, n_estimators=300 ..............
# [CV]  max_depth=10, min_samples_leaf=1, n_estimators=300, score=0.901, total=   2.3s
# [CV] max_depth=10, min_samples_leaf=2, n_estimators=250 ..............
# [CV]  max_depth=10, min_samples_leaf=2, n_estimators=250, score=0.961, total=   1.3s
# [CV] max_depth=10, min_samples_leaf=2, n_estimators=250 ..............
# [CV]  max_depth=10, min_samples_leaf=2, n_estimators=250, score=0.930, total=   1.1s
# [CV] max_depth=10, min_samples_leaf=2, n_estimators=250 ..............
# [CV]  max_depth=10, min_samples_leaf=2, n_estimators=250, score=0.947, total=   0.9s
# [CV] max_depth=10, min_samples_leaf=2, n_estimators=250 ..............
# [CV]  max_depth=10, min_samples_leaf=2, n_estimators=250, score=0.941, total=   1.1s
# [CV] max_depth=10, min_samples_leaf=2, n_estimators=250 ..............
# [CV]  max_depth=10, min_samples_leaf=2, n_estimators=250, score=0.902, total=   1.0s
# [CV] max_depth=10, min_samples_leaf=2, n_estimators=260 ..............
# [CV]  max_depth=10, min_samples_leaf=2, n_estimators=260, score=0.961, total=   1.0s
# [CV] max_depth=10, min_samples_leaf=2, n_estimators=260 ..............
# [CV]  max_depth=10, min_samples_leaf=2, n_estimators=260, score=0.930, total=   1.1s
# [CV] max_depth=10, min_samples_leaf=2, n_estimators=260 ..............
# [CV]  max_depth=10, min_samples_leaf=2, n_estimators=260, score=0.947, total=   1.3s
# [CV] max_depth=10, min_samples_leaf=2, n_estimators=260 ..............
# [CV]  max_depth=10, min_samples_leaf=2, n_estimators=260, score=0.940, total=   1.4s
# [CV] max_depth=10, min_samples_leaf=2, n_estimators=260 ..............
# [CV]  max_depth=10, min_samples_leaf=2, n_estimators=260, score=0.897, total=   1.2s
# [CV] max_depth=10, min_samples_leaf=2, n_estimators=275 ..............
# [CV]  max_depth=10, min_samples_leaf=2, n_estimators=275, score=0.961, total=   1.1s
# [CV] max_depth=10, min_samples_leaf=2, n_estimators=275 ..............
# [CV]  max_depth=10, min_samples_leaf=2, n_estimators=275, score=0.931, total=   1.0s
# [CV] max_depth=10, min_samples_leaf=2, n_estimators=275 ..............
# [CV]  max_depth=10, min_samples_leaf=2, n_estimators=275, score=0.947, total=   1.3s
# [CV] max_depth=10, min_samples_leaf=2, n_estimators=275 ..............
# [CV]  max_depth=10, min_samples_leaf=2, n_estimators=275, score=0.940, total=   1.3s
# [CV] max_depth=10, min_samples_leaf=2, n_estimators=275 ..............
# [CV]  max_depth=10, min_samples_leaf=2, n_estimators=275, score=0.902, total=   1.0s
# [CV] max_depth=10, min_samples_leaf=2, n_estimators=285 ..............
# [CV]  max_depth=10, min_samples_leaf=2, n_estimators=285, score=0.961, total=   1.2s
# [CV] max_depth=10, min_samples_leaf=2, n_estimators=285 ..............
# [CV]  max_depth=10, min_samples_leaf=2, n_estimators=285, score=0.932, total=   1.3s
# [CV] max_depth=10, min_samples_leaf=2, n_estimators=285 ..............
# [CV]  max_depth=10, min_samples_leaf=2, n_estimators=285, score=0.947, total=   1.3s
# [CV] max_depth=10, min_samples_leaf=2, n_estimators=285 ..............
# [CV]  max_depth=10, min_samples_leaf=2, n_estimators=285, score=0.939, total=   1.2s
# [CV] max_depth=10, min_samples_leaf=2, n_estimators=285 ..............
# [CV]  max_depth=10, min_samples_leaf=2, n_estimators=285, score=0.898, total=   1.4s
# [CV] max_depth=10, min_samples_leaf=2, n_estimators=300 ..............
# [CV]  max_depth=10, min_samples_leaf=2, n_estimators=300, score=0.961, total=   1.2s
# [CV] max_depth=10, min_samples_leaf=2, n_estimators=300 ..............
# [CV]  max_depth=10, min_samples_leaf=2, n_estimators=300, score=0.929, total=   1.3s
# [CV] max_depth=10, min_samples_leaf=2, n_estimators=300 ..............
# [CV]  max_depth=10, min_samples_leaf=2, n_estimators=300, score=0.948, total=   1.2s
# [CV] max_depth=10, min_samples_leaf=2, n_estimators=300 ..............
# [CV]  max_depth=10, min_samples_leaf=2, n_estimators=300, score=0.940, total=   1.3s
# [CV] max_depth=10, min_samples_leaf=2, n_estimators=300 ..............
# [CV]  max_depth=10, min_samples_leaf=2, n_estimators=300, score=0.901, total=   1.2s
# [CV] max_depth=10, min_samples_leaf=3, n_estimators=250 ..............
# [CV]  max_depth=10, min_samples_leaf=3, n_estimators=250, score=0.959, total=   1.3s
# [CV] max_depth=10, min_samples_leaf=3, n_estimators=250 ..............
# [CV]  max_depth=10, min_samples_leaf=3, n_estimators=250, score=0.928, total=   1.0s
# [CV] max_depth=10, min_samples_leaf=3, n_estimators=250 ..............
# [CV]  max_depth=10, min_samples_leaf=3, n_estimators=250, score=0.947, total=   0.8s
# [CV] max_depth=10, min_samples_leaf=3, n_estimators=250 ..............
# [CV]  max_depth=10, min_samples_leaf=3, n_estimators=250, score=0.940, total=   0.9s
# [CV] max_depth=10, min_samples_leaf=3, n_estimators=250 ..............
# [CV]  max_depth=10, min_samples_leaf=3, n_estimators=250, score=0.896, total=   0.9s
# [CV] max_depth=10, min_samples_leaf=3, n_estimators=260 ..............
# [CV]  max_depth=10, min_samples_leaf=3, n_estimators=260, score=0.959, total=   0.9s
# [CV] max_depth=10, min_samples_leaf=3, n_estimators=260 ..............
# [CV]  max_depth=10, min_samples_leaf=3, n_estimators=260, score=0.930, total=   0.9s
# [CV] max_depth=10, min_samples_leaf=3, n_estimators=260 ..............
# [CV]  max_depth=10, min_samples_leaf=3, n_estimators=260, score=0.946, total=   0.8s
# [CV] max_depth=10, min_samples_leaf=3, n_estimators=260 ..............
# [CV]  max_depth=10, min_samples_leaf=3, n_estimators=260, score=0.941, total=   1.1s
# [CV] max_depth=10, min_samples_leaf=3, n_estimators=260 ..............
# [CV]  max_depth=10, min_samples_leaf=3, n_estimators=260, score=0.903, total=   1.3s
# [CV] max_depth=10, min_samples_leaf=3, n_estimators=275 ..............
# [CV]  max_depth=10, min_samples_leaf=3, n_estimators=275, score=0.959, total=   1.0s
# [CV] max_depth=10, min_samples_leaf=3, n_estimators=275 ..............
# [CV]  max_depth=10, min_samples_leaf=3, n_estimators=275, score=0.929, total=   0.9s
# [CV] max_depth=10, min_samples_leaf=3, n_estimators=275 ..............
# [CV]  max_depth=10, min_samples_leaf=3, n_estimators=275, score=0.947, total=   0.9s
# [CV] max_depth=10, min_samples_leaf=3, n_estimators=275 ..............
# [CV]  max_depth=10, min_samples_leaf=3, n_estimators=275, score=0.939, total=   1.0s
# [CV] max_depth=10, min_samples_leaf=3, n_estimators=275 ..............
# [CV]  max_depth=10, min_samples_leaf=3, n_estimators=275, score=0.901, total=   1.3s
# [CV] max_depth=10, min_samples_leaf=3, n_estimators=285 ..............
# [CV]  max_depth=10, min_samples_leaf=3, n_estimators=285, score=0.958, total=   1.0s
# [CV] max_depth=10, min_samples_leaf=3, n_estimators=285 ..............
# [CV]  max_depth=10, min_samples_leaf=3, n_estimators=285, score=0.929, total=   1.4s
# [CV] max_depth=10, min_samples_leaf=3, n_estimators=285 ..............
# [CV]  max_depth=10, min_samples_leaf=3, n_estimators=285, score=0.946, total=   1.1s
# [CV] max_depth=10, min_samples_leaf=3, n_estimators=285 ..............
# [CV]  max_depth=10, min_samples_leaf=3, n_estimators=285, score=0.941, total=   1.0s
# [CV] max_depth=10, min_samples_leaf=3, n_estimators=285 ..............
# [CV]  max_depth=10, min_samples_leaf=3, n_estimators=285, score=0.897, total=   1.0s
# [CV] max_depth=10, min_samples_leaf=3, n_estimators=300 ..............
# [CV]  max_depth=10, min_samples_leaf=3, n_estimators=300, score=0.958, total=   1.0s
# [CV] max_depth=10, min_samples_leaf=3, n_estimators=300 ..............
# [CV]  max_depth=10, min_samples_leaf=3, n_estimators=300, score=0.929, total=   1.0s
# [CV] max_depth=10, min_samples_leaf=3, n_estimators=300 ..............
# [CV]  max_depth=10, min_samples_leaf=3, n_estimators=300, score=0.947, total=   1.1s
# [CV] max_depth=10, min_samples_leaf=3, n_estimators=300 ..............
# [CV]  max_depth=10, min_samples_leaf=3, n_estimators=300, score=0.941, total=   1.4s
# [CV] max_depth=10, min_samples_leaf=3, n_estimators=300 ..............
# [CV]  max_depth=10, min_samples_leaf=3, n_estimators=300, score=0.900, total=   1.1s
# [CV] max_depth=11, min_samples_leaf=1, n_estimators=250 ..............
# [CV]  max_depth=11, min_samples_leaf=1, n_estimators=250, score=0.964, total=   1.0s
# [CV] max_depth=11, min_samples_leaf=1, n_estimators=250 ..............
# [CV]  max_depth=11, min_samples_leaf=1, n_estimators=250, score=0.938, total=   1.0s
# [CV] max_depth=11, min_samples_leaf=1, n_estimators=250 ..............
# [CV]  max_depth=11, min_samples_leaf=1, n_estimators=250, score=0.947, total=   1.0s
# [CV] max_depth=11, min_samples_leaf=1, n_estimators=250 ..............
# [CV]  max_depth=11, min_samples_leaf=1, n_estimators=250, score=0.935, total=   1.0s
# [CV] max_depth=11, min_samples_leaf=1, n_estimators=250 ..............
# [CV]  max_depth=11, min_samples_leaf=1, n_estimators=250, score=0.901, total=   1.0s
# [CV] max_depth=11, min_samples_leaf=1, n_estimators=260 ..............
# [CV]  max_depth=11, min_samples_leaf=1, n_estimators=260, score=0.963, total=   1.0s
# [CV] max_depth=11, min_samples_leaf=1, n_estimators=260 ..............
# [CV]  max_depth=11, min_samples_leaf=1, n_estimators=260, score=0.938, total=   1.5s
# [CV] max_depth=11, min_samples_leaf=1, n_estimators=260 ..............
# [CV]  max_depth=11, min_samples_leaf=1, n_estimators=260, score=0.946, total=   1.1s
# [CV] max_depth=11, min_samples_leaf=1, n_estimators=260 ..............
# [CV]  max_depth=11, min_samples_leaf=1, n_estimators=260, score=0.938, total=   1.0s
# [CV] max_depth=11, min_samples_leaf=1, n_estimators=260 ..............
# [CV]  max_depth=11, min_samples_leaf=1, n_estimators=260, score=0.905, total=   1.0s
# [CV] max_depth=11, min_samples_leaf=1, n_estimators=275 ..............
# [CV]  max_depth=11, min_samples_leaf=1, n_estimators=275, score=0.963, total=   1.1s
# [CV] max_depth=11, min_samples_leaf=1, n_estimators=275 ..............
# [CV]  max_depth=11, min_samples_leaf=1, n_estimators=275, score=0.937, total=   1.4s
# [CV] max_depth=11, min_samples_leaf=1, n_estimators=275 ..............
# [CV]  max_depth=11, min_samples_leaf=1, n_estimators=275, score=0.946, total=   1.4s
# [CV] max_depth=11, min_samples_leaf=1, n_estimators=275 ..............
# [CV]  max_depth=11, min_samples_leaf=1, n_estimators=275, score=0.934, total=   1.1s
# [CV] max_depth=11, min_samples_leaf=1, n_estimators=275 ..............
# [CV]  max_depth=11, min_samples_leaf=1, n_estimators=275, score=0.903, total=   1.1s
# [CV] max_depth=11, min_samples_leaf=1, n_estimators=285 ..............
# [CV]  max_depth=11, min_samples_leaf=1, n_estimators=285, score=0.963, total=   1.2s
# [CV] max_depth=11, min_samples_leaf=1, n_estimators=285 ..............
# [CV]  max_depth=11, min_samples_leaf=1, n_estimators=285, score=0.939, total=   1.2s
# [CV] max_depth=11, min_samples_leaf=1, n_estimators=285 ..............
# [CV]  max_depth=11, min_samples_leaf=1, n_estimators=285, score=0.947, total=   1.5s
# [CV] max_depth=11, min_samples_leaf=1, n_estimators=285 ..............
# [CV]  max_depth=11, min_samples_leaf=1, n_estimators=285, score=0.936, total=   1.2s
# [CV] max_depth=11, min_samples_leaf=1, n_estimators=285 ..............
# [CV]  max_depth=11, min_samples_leaf=1, n_estimators=285, score=0.902, total=   1.8s
# [CV] max_depth=11, min_samples_leaf=1, n_estimators=300 ..............
# [CV]  max_depth=11, min_samples_leaf=1, n_estimators=300, score=0.963, total=   1.5s
# [CV] max_depth=11, min_samples_leaf=1, n_estimators=300 ..............
# [CV]  max_depth=11, min_samples_leaf=1, n_estimators=300, score=0.936, total=   1.6s
# [CV] max_depth=11, min_samples_leaf=1, n_estimators=300 ..............
# [CV]  max_depth=11, min_samples_leaf=1, n_estimators=300, score=0.947, total=   1.2s
# [CV] max_depth=11, min_samples_leaf=1, n_estimators=300 ..............
# [CV]  max_depth=11, min_samples_leaf=1, n_estimators=300, score=0.935, total=   1.5s
# [CV] max_depth=11, min_samples_leaf=1, n_estimators=300 ..............
# [CV]  max_depth=11, min_samples_leaf=1, n_estimators=300, score=0.906, total=   1.2s
# [CV] max_depth=11, min_samples_leaf=2, n_estimators=250 ..............
# [CV]  max_depth=11, min_samples_leaf=2, n_estimators=250, score=0.962, total=   0.9s
# [CV] max_depth=11, min_samples_leaf=2, n_estimators=250 ..............
# [CV]  max_depth=11, min_samples_leaf=2, n_estimators=250, score=0.930, total=   1.0s
# [CV] max_depth=11, min_samples_leaf=2, n_estimators=250 ..............
# [CV]  max_depth=11, min_samples_leaf=2, n_estimators=250, score=0.947, total=   0.9s
# [CV] max_depth=11, min_samples_leaf=2, n_estimators=250 ..............
# [CV]  max_depth=11, min_samples_leaf=2, n_estimators=250, score=0.941, total=   0.9s
# [CV] max_depth=11, min_samples_leaf=2, n_estimators=250 ..............
# [CV]  max_depth=11, min_samples_leaf=2, n_estimators=250, score=0.902, total=   0.9s
# [CV] max_depth=11, min_samples_leaf=2, n_estimators=260 ..............
# [CV]  max_depth=11, min_samples_leaf=2, n_estimators=260, score=0.961, total=   1.0s
# [CV] max_depth=11, min_samples_leaf=2, n_estimators=260 ..............
# [CV]  max_depth=11, min_samples_leaf=2, n_estimators=260, score=0.930, total=   1.0s
# [CV] max_depth=11, min_samples_leaf=2, n_estimators=260 ..............
# [CV]  max_depth=11, min_samples_leaf=2, n_estimators=260, score=0.947, total=   1.2s
# [CV] max_depth=11, min_samples_leaf=2, n_estimators=260 ..............
# [CV]  max_depth=11, min_samples_leaf=2, n_estimators=260, score=0.938, total=   1.3s
# [CV] max_depth=11, min_samples_leaf=2, n_estimators=260 ..............
# [CV]  max_depth=11, min_samples_leaf=2, n_estimators=260, score=0.901, total=   1.0s
# [CV] max_depth=11, min_samples_leaf=2, n_estimators=275 ..............
# [CV]  max_depth=11, min_samples_leaf=2, n_estimators=275, score=0.962, total=   1.0s
# [CV] max_depth=11, min_samples_leaf=2, n_estimators=275 ..............
# [CV]  max_depth=11, min_samples_leaf=2, n_estimators=275, score=0.931, total=   1.4s
# [CV] max_depth=11, min_samples_leaf=2, n_estimators=275 ..............
# [CV]  max_depth=11, min_samples_leaf=2, n_estimators=275, score=0.947, total=   1.4s
# [CV] max_depth=11, min_samples_leaf=2, n_estimators=275 ..............
# [CV]  max_depth=11, min_samples_leaf=2, n_estimators=275, score=0.940, total=   1.2s
# [CV] max_depth=11, min_samples_leaf=2, n_estimators=275 ..............
# [CV]  max_depth=11, min_samples_leaf=2, n_estimators=275, score=0.898, total=   1.1s
# [CV] max_depth=11, min_samples_leaf=2, n_estimators=285 ..............
# [CV]  max_depth=11, min_samples_leaf=2, n_estimators=285, score=0.961, total=   1.6s
# [CV] max_depth=11, min_samples_leaf=2, n_estimators=285 ..............
# [CV]  max_depth=11, min_samples_leaf=2, n_estimators=285, score=0.931, total=   1.3s
# [CV] max_depth=11, min_samples_leaf=2, n_estimators=285 ..............
# [CV]  max_depth=11, min_samples_leaf=2, n_estimators=285, score=0.946, total=   1.1s
# [CV] max_depth=11, min_samples_leaf=2, n_estimators=285 ..............
# [CV]  max_depth=11, min_samples_leaf=2, n_estimators=285, score=0.938, total=   1.1s
# [CV] max_depth=11, min_samples_leaf=2, n_estimators=285 ..............
# [CV]  max_depth=11, min_samples_leaf=2, n_estimators=285, score=0.898, total=   1.5s
# [CV] max_depth=11, min_samples_leaf=2, n_estimators=300 ..............
# [CV]  max_depth=11, min_samples_leaf=2, n_estimators=300, score=0.961, total=   1.4s
# [CV] max_depth=11, min_samples_leaf=2, n_estimators=300 ..............
# [CV]  max_depth=11, min_samples_leaf=2, n_estimators=300, score=0.930, total=   1.7s
# [CV] max_depth=11, min_samples_leaf=2, n_estimators=300 ..............
# [CV]  max_depth=11, min_samples_leaf=2, n_estimators=300, score=0.947, total=   1.1s
# [CV] max_depth=11, min_samples_leaf=2, n_estimators=300 ..............
# [CV]  max_depth=11, min_samples_leaf=2, n_estimators=300, score=0.940, total=   1.1s
# [CV] max_depth=11, min_samples_leaf=2, n_estimators=300 ..............
# [CV]  max_depth=11, min_samples_leaf=2, n_estimators=300, score=0.900, total=   1.1s
# [CV] max_depth=11, min_samples_leaf=3, n_estimators=250 ..............
# [CV]  max_depth=11, min_samples_leaf=3, n_estimators=250, score=0.958, total=   0.9s
# [CV] max_depth=11, min_samples_leaf=3, n_estimators=250 ..............
# [CV]  max_depth=11, min_samples_leaf=3, n_estimators=250, score=0.929, total=   0.9s
# [CV] max_depth=11, min_samples_leaf=3, n_estimators=250 ..............
# [CV]  max_depth=11, min_samples_leaf=3, n_estimators=250, score=0.947, total=   0.9s
# [CV] max_depth=11, min_samples_leaf=3, n_estimators=250 ..............
# [CV]  max_depth=11, min_samples_leaf=3, n_estimators=250, score=0.941, total=   0.8s
# [CV] max_depth=11, min_samples_leaf=3, n_estimators=250 ..............
# [CV]  max_depth=11, min_samples_leaf=3, n_estimators=250, score=0.897, total=   0.9s
# [CV] max_depth=11, min_samples_leaf=3, n_estimators=260 ..............
# [CV]  max_depth=11, min_samples_leaf=3, n_estimators=260, score=0.958, total=   0.9s
# [CV] max_depth=11, min_samples_leaf=3, n_estimators=260 ..............
# [CV]  max_depth=11, min_samples_leaf=3, n_estimators=260, score=0.930, total=   0.9s
# [CV] max_depth=11, min_samples_leaf=3, n_estimators=260 ..............
# [CV]  max_depth=11, min_samples_leaf=3, n_estimators=260, score=0.946, total=   0.9s
# [CV] max_depth=11, min_samples_leaf=3, n_estimators=260 ..............
# [CV]  max_depth=11, min_samples_leaf=3, n_estimators=260, score=0.941, total=   0.9s
# [CV] max_depth=11, min_samples_leaf=3, n_estimators=260 ..............
# [CV]  max_depth=11, min_samples_leaf=3, n_estimators=260, score=0.899, total=   0.8s
# [CV] max_depth=11, min_samples_leaf=3, n_estimators=275 ..............
# [CV]  max_depth=11, min_samples_leaf=3, n_estimators=275, score=0.958, total=   0.9s
# [CV] max_depth=11, min_samples_leaf=3, n_estimators=275 ..............
# [CV]  max_depth=11, min_samples_leaf=3, n_estimators=275, score=0.928, total=   1.3s
# [CV] max_depth=11, min_samples_leaf=3, n_estimators=275 ..............
# [CV]  max_depth=11, min_samples_leaf=3, n_estimators=275, score=0.946, total=   1.3s
# [CV] max_depth=11, min_samples_leaf=3, n_estimators=275 ..............
# [CV]  max_depth=11, min_samples_leaf=3, n_estimators=275, score=0.942, total=   1.3s
# [CV] max_depth=11, min_samples_leaf=3, n_estimators=275 ..............
# [CV]  max_depth=11, min_samples_leaf=3, n_estimators=275, score=0.899, total=   1.1s
# [CV] max_depth=11, min_samples_leaf=3, n_estimators=285 ..............
# [CV]  max_depth=11, min_samples_leaf=3, n_estimators=285, score=0.958, total=   1.0s
# [CV] max_depth=11, min_samples_leaf=3, n_estimators=285 ..............
# [CV]  max_depth=11, min_samples_leaf=3, n_estimators=285, score=0.930, total=   1.0s
# [CV] max_depth=11, min_samples_leaf=3, n_estimators=285 ..............
# [CV]  max_depth=11, min_samples_leaf=3, n_estimators=285, score=0.947, total=   0.9s
# [CV] max_depth=11, min_samples_leaf=3, n_estimators=285 ..............
# [CV]  max_depth=11, min_samples_leaf=3, n_estimators=285, score=0.939, total=   1.0s
# [CV] max_depth=11, min_samples_leaf=3, n_estimators=285 ..............
# [CV]  max_depth=11, min_samples_leaf=3, n_estimators=285, score=0.900, total=   1.0s
# [CV] max_depth=11, min_samples_leaf=3, n_estimators=300 ..............
# [CV]  max_depth=11, min_samples_leaf=3, n_estimators=300, score=0.958, total=   1.0s
# [CV] max_depth=11, min_samples_leaf=3, n_estimators=300 ..............
# [CV]  max_depth=11, min_samples_leaf=3, n_estimators=300, score=0.930, total=   1.0s
# [CV] max_depth=11, min_samples_leaf=3, n_estimators=300 ..............
# [CV]  max_depth=11, min_samples_leaf=3, n_estimators=300, score=0.947, total=   1.1s
# [CV] max_depth=11, min_samples_leaf=3, n_estimators=300 ..............
# [CV]  max_depth=11, min_samples_leaf=3, n_estimators=300, score=0.940, total=   1.1s
# [CV] max_depth=11, min_samples_leaf=3, n_estimators=300 ..............
# [CV]  max_depth=11, min_samples_leaf=3, n_estimators=300, score=0.899, total=   1.5s
# [Parallel(n_jobs=1)]: Done 225 out of 225 | elapsed:  4.5min finished
# GridSearchCV(cv=5, error_score=nan,
#              estimator=RandomForestRegressor(bootstrap=True, ccp_alpha=0.0,
#                                              criterion='mse', max_depth=None,
#                                              max_features='auto',
#                                              max_leaf_nodes=None,
#                                              max_samples=None,
#                                              min_impurity_decrease=0.0,
#                                              min_impurity_split=None,
#                                              min_samples_leaf=1,
#                                              min_samples_split=2,
#                                              min_weight_fraction_leaf=0.0,
#                                              n_estimators=100, n_jobs=None,
#                                              oob_score=False, random_state=None,
#                                              verbose=0, warm_start=False),
#              iid='deprecated', n_jobs=None,
#              param_grid={'max_depth': [9, 10, 11],
#                          'min_samples_leaf': [1, 2, 3],
#                          'n_estimators': [250, 260, 275, 285, 300]},
#              pre_dispatch='2*n_jobs', refit=True, return_train_score=False,
#              scoring=None, verbose=3)

# %%
random_grid.best_score_
# Out:
# 0.937881351058218

# %%
random_grid.best_params_
# Out:
# {'max_depth': 11, 'min_samples_leaf': 1, 'n_estimators': 260}

# %%
hyundai_model=RandomForestRegressor(n_estimators=260,max_depth=11,min_samples_leaf=1)

# %%
hyundai_model.fit(Newf_df,y)
# Out:
# RandomForestRegressor(bootstrap=True, ccp_alpha=0.0, criterion='mse',
#                       max_depth=11, max_features='auto', max_leaf_nodes=None,
#                       max_samples=None, min_impurity_decrease=0.0,
#                       min_impurity_split=None, min_samples_leaf=1,
#                       min_samples_split=2, min_weight_fraction_leaf=0.0,
#                       n_estimators=260, n_jobs=None, oob_score=False,
#                       random_state=None, verbose=0, warm_start=False)

# %%
pickle.dump(hyundai_model,open('hyundai_model.pkl','wb'))
